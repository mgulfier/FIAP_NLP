# %%
import spacy

# %%
import pandas as pd

#https://s3.amazonaws.com/aulas-fiap/imdb-reviews-pt-br.csv
df_original = pd.read_csv('https://s3.amazonaws.com/aulas-fiap/imdb-reviews-pt-br.csv')

df_original.describe()
# Out:
#                  id
# count  49459.000000
# mean   24730.960917
# std    14277.792868
# min        1.000000
# 25%    12366.500000
# 50%    24731.000000
# 75%    37095.500000
# max    49460.000000

# %%
#df = df_original.sample(5000,random_state=71)
df = df_original

# %%
df.text_pt = df.text_pt.str.lower()

# %%
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer




vect = TfidfVectorizer(ngram_range=(1,1), use_idf=True)
vect.fit(df.text_pt)
text_vect = vect.transform(df.text_pt)

X_train,X_test,y_train,y_test = train_test_split(
    text_vect, 
    df.sentiment,
    test_size = 0.2, 
    random_state = 42
)

# %%
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)

y_prediction = tree.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.7076632006864927

# %%
from sklearn.model_selection import GridSearchCV


print(tree.get_params())

parametros = {'criterion': ['gini','entropy'],
              'splitter': ['random','best'],
              'max_depth': [3,5,9,11],
              'min_samples_split': [2,4,6,8] }
        
tree_opt = GridSearchCV(tree, parametros, scoring='f1_weighted')

tree_opt.fit(X_train, y_train)

y_prediction = tree_opt.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')
print(f1)
print(tree_opt.get_params())
# Out:
# {'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': False, 'random_state': 42, 'splitter': 'best'}
# 0.6842640441869862
# {'cv': None, 'error_score': 'raise', 'estimator__class_weight': None, 'estimator__criterion': 'gini', 'estimator__max_depth': None, 'estimator__max_features': None, 'estimator__max_leaf_nodes': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_impurity_split': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__presort': False, 'estimator__random_state': 42, 'estimator__splitter': 'best', 'estimator': DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'), 'fit_params': None, 'iid': True, 'n_jobs': 1, 'param_grid': {'criterion': ['gini', 'entropy'], 'splitter': ['random', 'best'], 'max_depth': [3, 5, 9, 11], 'min_samples_split': [2, 4, 6, 8]}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': 'warn', 'scoring': 'f1_weighted', 'verbose': 0}

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)

neigh.fit(X_train, y_train)

y_prediction = neigh.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.7800344502570297

# %%
from sklearn.model_selection import GridSearchCV


print(neigh.get_params())

parametros = {'n_neighbors': [3,5,7],
              'weights': ['uniform','distance'],
              'algorithm': ['ball_tree','kd_tree','brute'],
               'p' : [1,2]}
        
neigh_opt = GridSearchCV(neigh, parametros, scoring='f1_weighted')

neigh_opt.fit(X_train, y_train)

y_prediction = neigh_opt.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')
print(f1)
print(neigh_opt.get_params())
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': 1, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\neighbors\base.py:212: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# 0.6916682803246679
# {'cv': None, 'error_score': 'raise', 'estimator__algorithm': 'auto', 'estimator__leaf_size': 30, 'estimator__metric': 'minkowski', 'estimator__metric_params': None, 'estimator__n_jobs': 1, 'estimator__n_neighbors': 5, 'estimator__p': 2, 'estimator__weights': 'uniform', 'estimator': KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'), 'fit_params': None, 'iid': True, 'n_jobs': 1, 'param_grid': {'n_neighbors': [3, 5, 7], 'weights': ['uniform', 'distance'], 'algorithm': ['ball_tree', 'kd_tree', 'brute'], 'p': [1, 2]}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': 'warn', 'scoring': 'f1_weighted', 'verbose': 0}

# %%
#### Melhor até o momento ##### 
#### F1 Score de 82,29%

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

svm_clf = SVC(C=100, kernel='linear',random_state =42)
svm_clf.fit(X_train, y_train)

y_prediction = svm_clf.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.8737282798268138

# %%
from sklearn.model_selection import GridSearchCV


print(svm_clf.get_params())

#parametros = {'kernel': ['linear', 'poly', 'rbf'],
#              'C': [1.0,2.0,100.0],
#              'degree': [2,3,4,5],
#              'gamma': ['auto','scale'],
#              'coef0' : [0.0,1.0,4.0],
#              'decision_function_shape' :['ovo','ovr'],
#              'shrinking' : [True,False]}

parametros = {'kernel': ['linear', 'poly', 'rbf'],
              'C': [90.0,100.0,120.0],
              'degree': [3,4],
              'decision_function_shape' :['ovo','ovr'] }


svm_opt = GridSearchCV(svm_clf, parametros, scoring='f1_weighted')

svm_opt.fit(X_train, y_train)

y_prediction = svm_opt.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')
print(f1)
print(svm_opt.get_params())
# Out:
# {'C': 100, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'auto', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': 42, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.8229665225949718
# {'cv': None, 'error_score': 'raise', 'estimator__C': 100, 'estimator__cache_size': 200, 'estimator__class_weight': None, 'estimator__coef0': 0.0, 'estimator__decision_function_shape': 'ovr', 'estimator__degree': 3, 'estimator__gamma': 'auto', 'estimator__kernel': 'linear', 'estimator__max_iter': -1, 'estimator__probability': False, 'estimator__random_state': 42, 'estimator__shrinking': True, 'estimator__tol': 0.001, 'estimator__verbose': False, 'estimator': SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=42, shrinking=True,
#   tol=0.001, verbose=False), 'fit_params': None, 'iid': True, 'n_jobs': 1, 'param_grid': {'kernel': ['linear', 'poly', 'rbf'], 'C': [90.0, 100.0, 200.0], 'degree': [2, 3, 4], 'decision_function_shape': ['ovo', 'ovr']}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': 'warn', 'scoring': 'f1_weighted', 'verbose': 0}

# %%
from nltk.classify import MaxentClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

#rand_forest = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#            max_depth=2, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)


rand_forest = RandomForestClassifier(n_estimators=200,random_state=42,max_depth=10)
rand_forest.fit(X_train, y_train)

y_prediction = rand_forest.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.8001344263475642

# %%
from sklearn.model_selection import GridSearchCV


print(rand_forest.get_params())






parametros = {
              'max_depth': [40, None],
              'max_features': ['auto', 'sqrt'],
              'n_estimators': [200, 400, 1000]}


rand_forest_opt = GridSearchCV(rand_forest, parametros, scoring='f1_weighted')

rand_forest_opt.fit(X_train, y_train)

y_prediction = rand_forest_opt.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')
print(f1)
print(rand_forest_opt.get_params())
# Out:
# {'bootstrap': True, 'class_weight': None, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200, 'n_jobs': 1, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# 0.8099498157108039
# {'cv': None, 'error_score': 'raise', 'estimator__bootstrap': True, 'estimator__class_weight': None, 'estimator__criterion': 'gini', 'estimator__max_depth': 10, 'estimator__max_features': 'auto', 'estimator__max_leaf_nodes': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_impurity_split': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__n_estimators': 200, 'estimator__n_jobs': 1, 'estimator__oob_score': False, 'estimator__random_state': 42, 'estimator__verbose': 0, 'estimator__warm_start': False, 'estimator': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False), 'fit_params': None, 'iid': True, 'n_jobs': 1, 'param_grid': {'max_depth': [40, None], 'max_features': ['auto', 'sqrt'], 'n_estimators': [200, 400, 1000]}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': 'warn', 'scoring': 'f1_weighted', 'verbose': 0}

# %%
#### Bom modelo também ####
from sklearn.naive_bayes import BernoulliNB

naive_berno = BernoulliNB()

naive_berno.fit(X_train,y_train)

y_prediction = naive_berno.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.8570078748299506

# %%
from sklearn.naive_bayes import MultinomialNB

naive_multi = MultinomialNB()

naive_multi.fit(X_train,y_train)

y_prediction = naive_multi.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.8616663092276419

# %%
from xgboost import XGBClassifier
import xgboost as xgb





def xgb_f1(y,t):
    t = t.get_label()
    y_bin = [1. if y_cont > 0.5 else 0. for y_cont in y] # binaryzing your output
    return 'f1',f1_score(t,y_bin)

clf = xgb.XGBClassifier(max_depth=15, learning_rate=0.004,
                            n_estimators=200,
                            booster='gbtree',
                            silent=True,   objective='binary:logistic',
                            nthread=-1, gamma=0,
                            min_child_weight=1, max_delta_step=0, subsample=0.8,
                            colsample_bytree=0.6,
                            base_score=0.5,
                            seed=0, missing=None)


#clf.fit(X_train, y_train, eval_metric=xgb_f1,
#         eval_set=[(X_train, y_train), (X_test, y_test)],
#         early_stopping_rounds=900)


clf.fit(X_train, y_train, eval_metric=xgb_f1,
         eval_set=[(X_train, y_train)],
         early_stopping_rounds=900)

y_pred = clf.predict(X_test)


f1 = f1_score(y_pred, y_test, average='weighted')


print(f1)
# Out:
# [0]	validation_0-error:0.227791	validation_0-f1:0.787595
# Multiple eval metrics have been passed: 'validation_0-f1' will be used for early stopping.
#
# Will train until validation_0-f1 hasn't improved in 900 rounds.
# [1]	validation_0-error:0.191549	validation_0-f1:0.816467
# [2]	validation_0-error:0.179341	validation_0-f1:0.832111
# [3]	validation_0-error:0.173023	validation_0-f1:0.837147
# [4]	validation_0-error:0.170066	validation_0-f1:0.840692
# [5]	validation_0-error:0.166705	validation_0-f1:0.843459
# [6]	validation_0-error:0.165946	validation_0-f1:0.84443
# [7]	validation_0-error:0.160917	validation_0-f1:0.848668
# [8]	validation_0-error:0.158516	validation_0-f1:0.851177
# [9]	validation_0-error:0.157808	validation_0-f1:0.851869
# [10]	validation_0-error:0.155913	validation_0-f1:0.85404
# [11]	validation_0-error:0.154902	validation_0-f1:0.854835
# [12]	validation_0-error:0.155028	validation_0-f1:0.854803
# [13]	validation_0-error:0.155812	validation_0-f1:0.854513
# [14]	validation_0-error:0.153259	validation_0-f1:0.85692
# [15]	validation_0-error:0.155028	validation_0-f1:0.855371
# [16]	validation_0-error:0.156342	validation_0-f1:0.854303
# [17]	validation_0-error:0.153284	validation_0-f1:0.856833
# [18]	validation_0-error:0.150984	validation_0-f1:0.858711
# [19]	validation_0-error:0.150909	validation_0-f1:0.858685
# [20]	validation_0-error:0.150605	validation_0-f1:0.859215
# [21]	validation_0-error:0.149165	validation_0-f1:0.86038
# [22]	validation_0-error:0.150024	validation_0-f1:0.859629
# [23]	validation_0-error:0.150327	validation_0-f1:0.859286
# [24]	validation_0-error:0.149999	validation_0-f1:0.859908
# [25]	validation_0-error:0.147749	validation_0-f1:0.861823
# [26]	validation_0-error:0.147547	validation_0-f1:0.861881
# [27]	validation_0-error:0.147016	validation_0-f1:0.862199
# [28]	validation_0-error:0.146738	validation_0-f1:0.86256
# [29]	validation_0-error:0.147168	validation_0-f1:0.862298
# [30]	validation_0-error:0.146814	validation_0-f1:0.862538
# [31]	validation_0-error:0.145298	validation_0-f1:0.863803
# [32]	validation_0-error:0.145551	validation_0-f1:0.863579
# [33]	validation_0-error:0.145778	validation_0-f1:0.863512
# [34]	validation_0-error:0.145904	validation_0-f1:0.863442
# [35]	validation_0-error:0.145702	validation_0-f1:0.86376
# [36]	validation_0-error:0.14593	validation_0-f1:0.863602
# [37]	validation_0-error:0.145551	validation_0-f1:0.864024
# [38]	validation_0-error:0.145652	validation_0-f1:0.864039
# [39]	validation_0-error:0.145702	validation_0-f1:0.864004
# [40]	validation_0-error:0.144944	validation_0-f1:0.864699
# [41]	validation_0-error:0.144262	validation_0-f1:0.865346
# [42]	validation_0-error:0.144717	validation_0-f1:0.864997
# [43]	validation_0-error:0.143377	validation_0-f1:0.866187
# [44]	validation_0-error:0.142189	validation_0-f1:0.867173
# [45]	validation_0-error:0.142998	validation_0-f1:0.866418
# [46]	validation_0-error:0.142467	validation_0-f1:0.866942
# [47]	validation_0-error:0.142467	validation_0-f1:0.866986
# [48]	validation_0-error:0.143023	validation_0-f1:0.866542
# [49]	validation_0-error:0.141886	validation_0-f1:0.867507
# [50]	validation_0-error:0.141608	validation_0-f1:0.867645
# [51]	validation_0-error:0.141734	validation_0-f1:0.867461
# [52]	validation_0-error:0.142316	validation_0-f1:0.866933
# [53]	validation_0-error:0.142189	validation_0-f1:0.867067
# [54]	validation_0-error:0.141911	validation_0-f1:0.867386
# [55]	validation_0-error:0.142214	validation_0-f1:0.867015
# [56]	validation_0-error:0.14176	validation_0-f1:0.867459
# [57]	validation_0-error:0.141608	validation_0-f1:0.86757
# [58]	validation_0-error:0.141077	validation_0-f1:0.868119
# [59]	validation_0-error:0.140546	validation_0-f1:0.868587
# [60]	validation_0-error:0.140091	validation_0-f1:0.869006
# [61]	validation_0-error:0.139662	validation_0-f1:0.869318
# [62]	validation_0-error:0.139182	validation_0-f1:0.869783
# [63]	validation_0-error:0.139182	validation_0-f1:0.869685
# [64]	validation_0-error:0.138929	validation_0-f1:0.869897
# [65]	validation_0-error:0.138979	validation_0-f1:0.869917
# [66]	validation_0-error:0.138954	validation_0-f1:0.869901
# [67]	validation_0-error:0.138575	validation_0-f1:0.870289
# [68]	validation_0-error:0.138727	validation_0-f1:0.870246
# [69]	validation_0-error:0.138803	validation_0-f1:0.870129
# [70]	validation_0-error:0.138853	validation_0-f1:0.8701
# [71]	validation_0-error:0.139182	validation_0-f1:0.869814
# [72]	validation_0-error:0.13951	validation_0-f1:0.869448
# [73]	validation_0-error:0.139333	validation_0-f1:0.869635
# [74]	validation_0-error:0.138373	validation_0-f1:0.870534
# [75]	validation_0-error:0.138575	validation_0-f1:0.870332
# [76]	validation_0-error:0.137716	validation_0-f1:0.871063
# [77]	validation_0-error:0.137589	validation_0-f1:0.871239
# [78]	validation_0-error:0.137387	validation_0-f1:0.871398
# [79]	validation_0-error:0.137337	validation_0-f1:0.871421
# [80]	validation_0-error:0.137033	validation_0-f1:0.871669
# [81]	validation_0-error:0.136528	validation_0-f1:0.87213
# [82]	validation_0-error:0.136553	validation_0-f1:0.872097
# [83]	validation_0-error:0.136629	validation_0-f1:0.872029
# [84]	validation_0-error:0.136174	validation_0-f1:0.872504
# [85]	validation_0-error:0.136174	validation_0-f1:0.872389
# [86]	validation_0-error:0.136225	validation_0-f1:0.872299
# [87]	validation_0-error:0.13668	validation_0-f1:0.871952
# [88]	validation_0-error:0.136907	validation_0-f1:0.871729
# [89]	validation_0-error:0.136958	validation_0-f1:0.871688
# [90]	validation_0-error:0.137059	validation_0-f1:0.871618
# [91]	validation_0-error:0.13668	validation_0-f1:0.871994
# [92]	validation_0-error:0.136503	validation_0-f1:0.872181
# [93]	validation_0-error:0.136831	validation_0-f1:0.87187
# [94]	validation_0-error:0.13673	validation_0-f1:0.872007
# [95]	validation_0-error:0.136932	validation_0-f1:0.871848
# [96]	validation_0-error:0.136831	validation_0-f1:0.871997
# [97]	validation_0-error:0.136831	validation_0-f1:0.871949
# [98]	validation_0-error:0.13673	validation_0-f1:0.872013
# [99]	validation_0-error:0.136882	validation_0-f1:0.871914
# [100]	validation_0-error:0.13673	validation_0-f1:0.872086
# [101]	validation_0-error:0.136578	validation_0-f1:0.872234
# [102]	validation_0-error:0.136528	validation_0-f1:0.872227
# [103]	validation_0-error:0.136402	validation_0-f1:0.872348
# [104]	validation_0-error:0.136022	validation_0-f1:0.8727
# [105]	validation_0-error:0.136149	validation_0-f1:0.872518
# [106]	validation_0-error:0.13577	validation_0-f1:0.87287
# [107]	validation_0-error:0.13577	validation_0-f1:0.872906
# [108]	validation_0-error:0.135542	validation_0-f1:0.873122
# [109]	validation_0-error:0.135264	validation_0-f1:0.873421
# [110]	validation_0-error:0.13491	validation_0-f1:0.87374
# [111]	validation_0-error:0.135163	validation_0-f1:0.873504
# [112]	validation_0-error:0.134835	validation_0-f1:0.873814
# [113]	validation_0-error:0.134809	validation_0-f1:0.873847
# [114]	validation_0-error:0.134986	validation_0-f1:0.873696
# [115]	validation_0-error:0.134759	validation_0-f1:0.873882
# [116]	validation_0-error:0.134607	validation_0-f1:0.874054
# [117]	validation_0-error:0.13438	validation_0-f1:0.874258
# [118]	validation_0-error:0.134279	validation_0-f1:0.874359
# [119]	validation_0-error:0.133798	validation_0-f1:0.874787
# [120]	validation_0-error:0.133748	validation_0-f1:0.874834
# [121]	validation_0-error:0.133293	validation_0-f1:0.875254
# [122]	validation_0-error:0.133748	validation_0-f1:0.874829
# [123]	validation_0-error:0.133546	validation_0-f1:0.874994
# [124]	validation_0-error:0.133596	validation_0-f1:0.874941
# [125]	validation_0-error:0.133419	validation_0-f1:0.875121
# [126]	validation_0-error:0.13304	validation_0-f1:0.875497
# [127]	validation_0-error:0.132914	validation_0-f1:0.875606
# [128]	validation_0-error:0.132863	validation_0-f1:0.875612
# [129]	validation_0-error:0.132408	validation_0-f1:0.876044
# [130]	validation_0-error:0.132611	validation_0-f1:0.875872
# [131]	validation_0-error:0.132434	validation_0-f1:0.876023
# [132]	validation_0-error:0.132358	validation_0-f1:0.876062
# [133]	validation_0-error:0.132509	validation_0-f1:0.875943
# [134]	validation_0-error:0.132307	validation_0-f1:0.876115
# [135]	validation_0-error:0.132408	validation_0-f1:0.876044
# [136]	validation_0-error:0.13208	validation_0-f1:0.876314
# [137]	validation_0-error:0.132206	validation_0-f1:0.876204
# [138]	validation_0-error:0.132231	validation_0-f1:0.876166
# [139]	validation_0-error:0.132054	validation_0-f1:0.876375
# [140]	validation_0-error:0.131903	validation_0-f1:0.876506
# [141]	validation_0-error:0.131726	validation_0-f1:0.876721
# [142]	validation_0-error:0.131701	validation_0-f1:0.876736
# [143]	validation_0-error:0.131524	validation_0-f1:0.876916
# [144]	validation_0-error:0.131372	validation_0-f1:0.876994
# [145]	validation_0-error:0.130993	validation_0-f1:0.877334
# [146]	validation_0-error:0.130892	validation_0-f1:0.87744
# [147]	validation_0-error:0.131018	validation_0-f1:0.877331
# [148]	validation_0-error:0.130791	validation_0-f1:0.877518
# [149]	validation_0-error:0.130917	validation_0-f1:0.877356
# [150]	validation_0-error:0.130766	validation_0-f1:0.877521
# [151]	validation_0-error:0.130715	validation_0-f1:0.877557
# [152]	validation_0-error:0.130766	validation_0-f1:0.877538
# [153]	validation_0-error:0.130437	validation_0-f1:0.877832
# [154]	validation_0-error:0.130235	validation_0-f1:0.877963
# [155]	validation_0-error:0.130007	validation_0-f1:0.878197
# [156]	validation_0-error:0.129932	validation_0-f1:0.878265
# [157]	validation_0-error:0.129679	validation_0-f1:0.878456
# [158]	validation_0-error:0.129729	validation_0-f1:0.878408
# [159]	validation_0-error:0.129982	validation_0-f1:0.878189
# [160]	validation_0-error:0.12983	validation_0-f1:0.878342
# [161]	validation_0-error:0.129856	validation_0-f1:0.878316
# [162]	validation_0-error:0.129932	validation_0-f1:0.878276
# [163]	validation_0-error:0.129502	validation_0-f1:0.878653
# [164]	validation_0-error:0.129401	validation_0-f1:0.878713
# [165]	validation_0-error:0.129148	validation_0-f1:0.878933
# [166]	validation_0-error:0.128921	validation_0-f1:0.87916
# [167]	validation_0-error:0.128718	validation_0-f1:0.879361
# [168]	validation_0-error:0.128693	validation_0-f1:0.879394
# [169]	validation_0-error:0.128415	validation_0-f1:0.87964
# [170]	validation_0-error:0.12844	validation_0-f1:0.879613
# [171]	validation_0-error:0.128188	validation_0-f1:0.879873
# [172]	validation_0-error:0.128036	validation_0-f1:0.879992
# [173]	validation_0-error:0.12791	validation_0-f1:0.880114
# [174]	validation_0-error:0.12791	validation_0-f1:0.880119
# [175]	validation_0-error:0.127809	validation_0-f1:0.880197
# [176]	validation_0-error:0.127632	validation_0-f1:0.88036
# [177]	validation_0-error:0.12748	validation_0-f1:0.880485
# [178]	validation_0-error:0.127379	validation_0-f1:0.880591
# [179]	validation_0-error:0.127429	validation_0-f1:0.880533
# [180]	validation_0-error:0.127126	validation_0-f1:0.880851
# [181]	validation_0-error:0.127	validation_0-f1:0.880955
# [182]	validation_0-error:0.126722	validation_0-f1:0.881185
# [183]	validation_0-error:0.126772	validation_0-f1:0.881126
# [184]	validation_0-error:0.126469	validation_0-f1:0.881405
# [185]	validation_0-error:0.126216	validation_0-f1:0.881625
# [186]	validation_0-error:0.126292	validation_0-f1:0.881562
# [187]	validation_0-error:0.126039	validation_0-f1:0.881799
# [188]	validation_0-error:0.125888	validation_0-f1:0.881914
# [189]	validation_0-error:0.125686	validation_0-f1:0.882103
# [190]	validation_0-error:0.125761	validation_0-f1:0.882035
# [191]	validation_0-error:0.12561	validation_0-f1:0.882172
# [192]	validation_0-error:0.125534	validation_0-f1:0.882212
# [193]	validation_0-error:0.125408	validation_0-f1:0.882333
# [194]	validation_0-error:0.125256	validation_0-f1:0.882465
# [195]	validation_0-error:0.125231	validation_0-f1:0.882463
# [196]	validation_0-error:0.125079	validation_0-f1:0.882622
# [197]	validation_0-error:0.125155	validation_0-f1:0.882548
# [198]	validation_0-error:0.124801	validation_0-f1:0.882875
# [199]	validation_0-error:0.124498	validation_0-f1:0.883154
# 0.7155196539942843
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
import spacy

pt = spacy.load('pt_core_news_sm')

nlp = spacy.load('pt')



stop_words_spacy = nlp.Defaults.stop_words


import pandas as pd

from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer




vect = TfidfVectorizer(ngram_range=(1,1), use_idf=True,stop_words=stop_words_spacy)
vect.fit(df.text_pt)
text_vect = vect.transform(df.text_pt)

X_train,X_test,y_train,y_test = train_test_split(
    text_vect, 
    df.sentiment,
    test_size = 0.2, 
    random_state = 42
)

# %%
tree = DecisionTreeClassifier(random_state=42)
tree.fit(X_train, y_train)

y_prediction = tree.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)

# %%
#### Bom modelo também ####
from sklearn.naive_bayes import BernoulliNB

naive_berno = BernoulliNB()

naive_berno.fit(X_train,y_train)

y_prediction = naive_berno.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.8543677396298509

# %%
from sklearn.naive_bayes import MultinomialNB

naive_multi = MultinomialNB()

naive_multi.fit(X_train,y_train)

y_prediction = naive_multi.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')

print(f1)
# Out:
# 0.8610960619816452

# %%
from sklearn.model_selection import GridSearchCV


print(naive_multi.get_params())






parametros = {
              'alpha': [1.0,2.0,4.0],
              'fit_prior': [True, False]}


naive_multi_opt = GridSearchCV(naive_multi, parametros, scoring='f1_weighted')

naive_multi_opt.fit(X_train, y_train)

y_prediction = naive_multi_opt.predict(X_test)

f1 = f1_score(y_prediction, y_test, average='weighted')
print(f1)
print(naive_multi_opt.get_params())
# Out:
# {'alpha': 1.0, 'class_prior': None, 'fit_prior': True}
# 0.8620115909508999
# {'cv': None, 'error_score': 'raise', 'estimator__alpha': 1.0, 'estimator__class_prior': None, 'estimator__fit_prior': True, 'estimator': MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True), 'fit_params': None, 'iid': True, 'n_jobs': 1, 'param_grid': {'alpha': [1.0, 2.0, 4.0], 'fit_prior': [True, False]}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': 'warn', 'scoring': 'f1_weighted', 'verbose': 0}

# %%
        
#X_kfold = text_vect.todense()
#Y_kfold = df.sentiment.as_matrix()


X_kfold = X_train.todense()
Y_kfold = y_train.as_matrix()
    
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedShuffleSplit



#kf = StratifiedKFold(Y_kfold, k = 10, indices=True)
kf = StratifiedKFold(n_splits=10,random_state=42,shuffle=True)

#kf = StratifiedShuffleSplit(n_splits=10,random_state=42)

clf = naive_multi_opt


best_model = None 
best_f1 = -1 

for train_index, test_index in kf.split(X_kfold,Y_kfold):  
    X_train_kfold, X_test_kfold = X_kfold[train_index], X_kfold[test_index]
    y_train_kfold, y_test_kfold = Y_kfold[train_index], Y_kfold[test_index]
    
    print(X_train_kfold.shape[0])
    print(y_train_kfold.shape[0])
    clf.fit(X_train_kfold, y_train_kfold)
    y_prediction = clf.predict(X_test_kfold)
    f1 = f1_score(y_prediction, y_test_kfold, average='weighted')
    
    if f1 > best_f1:
       best_model = clf 
       best_f1 = f1 
    
    print(f1)

print("Melhor f1 = ")
print(best_f1)
X_final_test = X_test.todense()
Y_final_test = y_test.as_matrix()

y_pred = best_model.predict(X_final_test)

f1 = f1_score(y_pred,Y_final_test,average='weighted')
    
print(f1)
# Out:
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   import sys
# Para o x_kfold
# <class 'numpy.matrixlib.defmatrix.matrix'>
# <class 'numpy.matrixlib.defmatrix.matrix'>
# 3599
# 3599
# 0.81901390325663
# 3599
# 3599
# 0.8184317853877473
# 3599
# 3599
# 0.8754529955801765
# 3599
# 3599
# 0.838615872496744
# 3599
# 3599
# 0.8557783018134384
# 3601
# 3601
# 0.8151815456762306
# 3601
# 3601
# 0.7872997886378796
# 3601
# 3601
# 0.8004552498921087
# 3601
# 3601
# 0.8255252300997505
# 3601
# 3601
# 0.8155552432483077
# Melhor f1 =
# 0.8754529955801765
# 0.807044020590276
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\ipykernel_launcher.py:49: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
df.sentiment
# Out:
# 924      neg
# 8062     neg
# 10435    neg
# 27520    neg
# 2904     neg
# 32012    neg
# 42490    pos
# 39637    pos
# 4821     neg
# 6616     neg
# 43577    pos
# 5128     neg
# 22099    pos
# 48116    pos
# 19047    pos
# 40884    pos
# 3519     neg
# 11457    neg
# 26662    neg
# 16313    pos
# 23873    pos
# 8126     neg
# 14270    pos
# 8152     neg
# 20903    pos
# 45302    pos
# 24007    pos
# 40803    pos
# 2630     neg
# 5983     neg
#         ...
# 30355    neg
# 14499    pos
# 39048    pos
# 36028    neg
# 38201    pos
# 39556    pos
# 31353    neg
# 30226    neg
# 7290     neg
# 38838    pos
# 7487     neg
# 48670    pos
# 24687    pos
# 46413    pos
# 42498    pos
# 36060    neg
# 32697    neg
# 42894    pos
# 8964     neg
# 17153    pos
# 42877    pos
# 9487     neg
# 37801    pos
# 16283    pos
# 12772    pos
# 9129     neg
# 46573    pos
# 8300     neg
# 23858    pos
# 12242    neg
# Name: sentiment, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
# Out:
# C:\Users\nlp_fiap\Anaconda3_36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
max_fatures = 900
tokenizer = Tokenizer(num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(df.text_pt.values)
X = tokenizer.texts_to_sequences(df.text_pt.values)
X = pad_sequences(X)

# %%
 
from keras import backend as K

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

                 
    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
                 
                 
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
embed_dim = 128
lstm_out = 196

model = Sequential()
model.add(Embedding(max_fatures, embed_dim,input_length = X.shape[1]))
model.add(SpatialDropout1D(0.4))
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = [f1])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 711, 128)          115200
# _________________________________________________________________
# spatial_dropout1d_5 (Spatial (None, 711, 128)          0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 196)               254800
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 394
# =================================================================
# Total params: 370,394
# Trainable params: 370,394
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
Y = pd.get_dummies(df.sentiment).values
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)

print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (4000, 711) (4000, 2)
# (1000, 711) (1000, 2)

# %%
batch_size = 32
model.fit(X_train, Y_train, epochs = 8, batch_size=batch_size, verbose = 2)
# Out:
# Epoch 1/8
#  - 265s - loss: 0.6517 - f1: 0.6142
# Epoch 2/8
#  - 258s - loss: 0.5017 - f1: 0.7660
# Epoch 3/8
#  - 257s - loss: 0.4751 - f1: 0.7802
# Epoch 4/8
#  - 257s - loss: 0.4344 - f1: 0.8100
# Epoch 5/8
#  - 255s - loss: 0.4417 - f1: 0.7990
# Epoch 6/8
#  - 256s - loss: 0.3933 - f1: 0.8230
# Epoch 7/8
#  - 256s - loss: 0.4420 - f1: 0.7922
# Epoch 8/8
#  - 257s - loss: 0.3614 - f1: 0.8430

# %%
_,score_f1 = model.evaluate(X_test, Y_test, verbose = 2, batch_size = batch_size)

print("f1_score: %.4f" % (score_f1))
# Out:
# f1_score: 0.7360
